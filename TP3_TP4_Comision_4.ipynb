# %% [markdown]
# <a href="https://colab.research.google.com/github/CrisGutinardo97/Python-Ciencia-de-Datos/blob/main/TP3_TP4_Comision_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# # Nueva sección

# %% [markdown]
# # Nueva sección

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# Array aleatorio: [[9 2 1]
#  [5 2 1]
#  [3 2 1]
#  [0 7 9]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0)
print("Valor mínimo:", minimo)
print( matriz)
# Out:
# Valor mínimo: [-1 -1 -3 -2 -2]
# [[ 2  1  2  1 -1]
#  [ 0  2 -2 -2  1]
#  [-1  0 -1  2 -2]
#  [ 0  2 -3  1 -2]
#  [ 1 -1 -1 -1  2]]

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos'))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
cara=0
cruz=0
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    #print('salio cara')
    #print(dado[i])
    cara +=1
  else:
    #print('salio cruz')
    #print(dado[i])
    cruz +=1
# Out:
# ingrese la cantidad de simulación o lanzamientos11

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=cara/n
prom_cruz=cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 11 lanzamientos de sacar CARA es: 0.45454545454545453
# la probabilidad aproximada en 11 lanzamientos de sacar CRUZ es: 0.5454545454545454

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos'))
lanzamientos = np.random.randint(0, 2, m)

# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos10
# Probabilidad de cara: 0.50
# Probabilidad de sello: 0.50

# %%
import matplotlib.pyplot as plt
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np


#lanzamiento
probabilidad= [0.22, 0.22, 0.14, 0.14, 0.14, 0.14]

lanzamientos= np.random.choice([1,2,3,4,5,6], size= 100, p=probabilidad)

#probabilidad
prob2_bool= lanzamientos ==2
prob3_bool= lanzamientos == 3
prob5_bool= lanzamientos == 5
prob2_contador= np.sum (prob2_bool)
prob3_contador= np.sum (prob3_bool)
prob5_contador= np.sum (prob5_bool)
prob2= prob2_contador/ len(lanzamientos)
prob3=prob3_contador/ len(lanzamientos)
prob5=prob5_contador/ len(lanzamientos)


#grafico
numeros_x= [2,3, 6]
probabilidad_y= [prob2, prob3, prob5]
plt.bar(numeros_x, probabilidad_y)
plt.xlabel("Numeros")
plt.ylabel("Probabilidad")

plt.title("Grafico de los DADOS probabilidad de obtener 2, 3 y 5")

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np


#lanzamiento
probabilidad= [0.22, 0.22, 0.14, 0.14, 0.14, 0.14]

lanzamientos= np.random.choice([1,2,3,4,5,6], size= 100, p=probabilidad)

#probabilidad
prob2_bool= lanzamientos ==2
prob3_bool= lanzamientos == 3
prob5_bool= lanzamientos == 5
prob2_contador= np.sum (prob2_bool)
prob3_contador= np.sum (prob3_bool)
prob5_contador= np.sum (prob5_bool)
prob2= prob2_contador/ len(lanzamientos)
prob3=prob3_contador/ len(lanzamientos)
prob5=prob5_contador/ len(lanzamientos)
#grafico
numeros_x= [2, 3, 5]
probabilidad_y= [prob2, prob3, prob5]
plt.bar(numeros_x, probabilidad_y)
plt.xlabel("Numeros")
plt.ylabel("Probabilidad")

plt.title("Grafico de los DADOS probabilidad de obtener 2, 3 y 5")

plt.show()

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %%
#1
#matriz
ventas_diarias = np.array([
    [20, 15, 35, 29, 40, 41, 55],  # Prod A
    [44, 85, 95, 21, 31, 11, 75],  # Prod B
    [12, 99, 88, 20, 94, 77, 76],  # Prod C
    [10, 25, 85, 19, 60, 31, 71]   # Prod D
])
#media de ventas por cada producto
media_producto= np.mean(ventas_diarias, axis=1)
#mediana de ventas por cada producto
mediana_producto= np.median(ventas_diarias, axis=1)

#grafico
producto= ["Productos A","Productos B","Productos C","Productos D"]

plt.bar(producto, media_producto, label='Media', alpha=0.5)
plt.bar(producto, mediana_producto, label='Mediana', alpha=0.5)

plt.xlabel("Productos")
plt.ylabel("Ventas diarias")
plt.title("Gráfico de MEDIA Y MEDIANA de ventas por PRODUCTO: ")
plt.legend()

plt.show()

# %%
#2
#media de ventas por dia
media_ventas_por_dia= np.mean(ventas_diarias, axis= 0 )
#mediana de ventas por dia
mediana_ventas_por_dia= np.median(ventas_diarias, axis= 0 )
#grafico de trazos de linea
dias_semana=["Lunes","Martes","Miercoles","Jueves","VIernes","Sabado","Domingo"]

plt.plot(dias_semana, media_ventas_por_dia, label="Media")

plt.plot(dias_semana, mediana_ventas_por_dia, label="Mediana")

plt.xlabel("DIas de la semana")
plt.ylabel("Ventas diarias")
plt.title("Media y mediana de VENTAS POR DIA: ")
plt.legend()

plt.show()

# %%
#3
#Conclusión
#No entiendo mucho de marketing pero puedo sugerir en la conclusión que el potencial
#de ventas aumenta por algún motivo entre martes y miércoles, así como también los
#fines de semana. Y claramente el producto C es el que lidera en las ventas.
#En cuanto a estrategias vuelvo a repetir no estudié marketing, pero puedo proponer lo
#siguiente en vista de las gráficas:
#1-Realizar una inversión para mejorar la calidad de los productos
#sobre todo el A y el D
#2-Ampliar la publicidad
#3-Realizar ofertas y promociones en días lunes y jueves
#4-Crear promociones con los productos C y agregarles el A o el D
#5-Agregar más variedad de productos a la venta.

# %%
#4
#Desvío estandard
desvio_estandar_producto= np.std(ventas_diarias, axis= 1)
print("\nPRUEBA 1: \n",desvio_estandar_producto)


valor_mayor_desvio= np.argmax(desvio_estandar_producto)
valor_menor_desvio= np.argmin(desvio_estandar_producto)
print("\nPRUEBA 2: \n",valor_mayor_desvio)

#Grafico
plt.plot(dias_semana, ventas_diarias[valor_mayor_desvio], label="Producto con MAYOR DESVIO", linestyle='--')
plt.plot(dias_semana, ventas_diarias[valor_menor_desvio], label="Producto con MENOR DESVIO", linestyle='--')


plt.xlabel("Dias de la semana")
plt.ylabel("Ventas diarias")
plt.title("Ventas de producto CON MAYOR y MENOR DESVIO")

plt.legend()
plt.show()
# Out:
# PRUEBA 1:
#  [12.57954284 30.73720075 32.96689744 26.64582519]
#
# PRUEBA 2:
#  2

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %% [markdown]
# **Ayuda Como generar los datos**

# %%
#1
import numpy as np
import matplotlib.pyplot as plt

n_datos=int(input('Ingrese el tamaño de la muestra:' ))

sexo=np.random.choice(["MASCULINO", "FEMENINO", "NO ESPECIFICA"], size=n_datos)
edades= np.random.randint(28, 61, size=n_datos)
alturas= np.round(np.random.normal(187, 1, size=n_datos), decimals=2)
pesos = np.round(np.random.normal(80, 1,size= n_datos), decimals= 2)

horas_trabajo_estudio = np.round(np.random.normal(8, 1, size=n_datos), decimals=1)

horas_ejercicio = np.round(np.random.normal(2, 1, size=n_datos), decimals=1)
horas_descanso = np.round(24-horas_trabajo_estudio-horas_ejercicio, decimals=1)

tabla1=np.array([sexo, edades, alturas, pesos, horas_descanso, horas_trabajo_estudio, horas_ejercicio])
tabla2=np.swapaxes (tabla1, 0 ,1)

encabezado = ['SEXO', 'EDAD', 'ALTURA', 'PESO', 'HORAS DE DESCANSO', 'HORAS DE TRABAJO/ESTUDIO', 'HORAS DE EJERCICIO']
tabla_datos= np.vstack((encabezado, tabla2))
print(tabla_datos)

#2

media_altura= np.mean(alturas)
media_peso= np.mean(pesos)
media_hs_desc= np.mean(horas_descanso)
media_hs_trab= np.mean(horas_trabajo_estudio)
media_hs_ejer= np.mean(horas_ejercicio)

lambda_peso= np.round((np.std(pesos)/media_peso), decimals=4)
lambda_altura= np.round((np.std(alturas)/media_altura), decimals=4)
lambda_hs_descanso = np.round((np.std(horas_descanso)/media_hs_desc), decimals=4)
lambda_hs_trab= np.round((np.std(horas_trabajo_estudio)/media_hs_trab), decimals=4)
lambda_hs_ejer= np.round((np.std(horas_ejercicio)/media_hs_ejer), decimals=4)

print("\nLa media de alturas es: ", media_altura)
print("La media de pesos es: ", media_peso)
print("La media de horas de trabajo es: ", media_hs_trab)
print("La media de horas de descanso es: ", media_hs_desc)
print("La media de horas de ejercicio es: ", media_hs_ejer)

print("\nLa variabilidad del peso es : ", lambda_peso)
print("La variabilidad de las alturas es : ", lambda_altura)
print("La variabilidad de las horas de trabajo es : ", lambda_hs_trab)
print("La variabilidad de las horas de descanso es : ", lambda_hs_descanso)
print("La variabilidad de las horas de ejercicio es : ", lambda_hs_ejer)
# Out:
# Ingrese el tamaño de la muestra:15
# [['SEXO' 'EDAD' 'ALTURA' 'PESO' 'HORAS DE DESCANSO'
#   'HORAS DE TRABAJO/ESTUDIO' 'HORAS DE EJERCICIO']
#  ['NO ESPECIFICA' '58' '187.27' '78.81' '13.6' '8.7' '1.7']
#  ['FEMENINO' '40' '188.93' '77.46' '14.2' '7.9' '1.9']
#  ['NO ESPECIFICA' '32' '186.12' '77.9' '14.0' '7.4' '2.6']
#  ['MASCULINO' '33' '186.97' '80.15' '16.1' '8.1' '-0.2']
#  ['MASCULINO' '51' '187.23' '77.68' '11.1' '10.5' '2.4']
#  ['NO ESPECIFICA' '36' '187.31' '79.24' '13.6' '7.7' '2.7']
#  ['NO ESPECIFICA' '30' '186.33' '79.1' '15.5' '6.4' '2.1']
#  ['NO ESPECIFICA' '36' '186.57' '81.1' '13.2' '8.1' '2.7']
#  ['MASCULINO' '42' '187.05' '79.97' '12.6' '9.7' '1.7']
#  ['MASCULINO' '53' '184.27' '79.08' '12.5' '9.2' '2.3']
#  ['MASCULINO' '46' '186.72' '78.98' '13.8' '7.8' '2.4']
#  ['MASCULINO' '55' '187.16' '79.32' '13.5' '9.5' '1.0']
#  ['FEMENINO' '53' '184.34' '78.88' '14.4' '7.2' '2.4']
#  ['NO ESPECIFICA' '43' '186.96' '80.68' '15.9' '7.5' '0.6']
#  ['FEMENINO' '38' '189.11' '79.7' '13.4' '7.0' '3.6']]
#
# La media de alturas es:  186.82266666666666
# La media de pesos es:  79.20333333333335
# La media de horas de trabajo es:  8.180000000000001
# La media de horas de descanso es:  13.826666666666666
# La media de horas de ejercicio es:  1.9933333333333334
#
# La variabilidad del peso es :  0.0126
# La variabilidad de las alturas es :  0.0068
# La variabilidad de las horas de trabajo es :  0.1332
# La variabilidad de las horas de descanso es :  0.092
# La variabilidad de las horas de ejercicio es :  0.4574

# %%
#3
fig, ax =plt.subplots(1,2, figsize=(20, 8))
ax[0].hist(pesos, bins=20, edgecolor='black')
ax[0].set_title('Distribución de Pesos')
ax[0].set_xlabel('Peso (kg)')
ax[0].set_ylabel('Frecuencia')
ax[1].hist(alturas, bins=20, edgecolor='black')
ax[1].set_title('Distribución de Alturas')
ax[1].set_xlabel('Altura (cm)')
ax[1].set_ylabel('Frecuencia')
plt.show()

# %%
#4 (los datos están muy dispersos)
plt.scatter(pesos,alturas)

plt.xlabel("Peso en kg")
plt.ylabel("Altura en cm")
plt.title("Peso vs Altura")

plt.show()

# %%
#5
plt.bar(range(n_datos),horas_descanso, label="Horas de descanso", alpha=0.8)
plt.bar(range(n_datos),horas_trabajo_estudio, label="Horas de trabajo/estudio")
plt.bar(range(n_datos),horas_ejercicio, label="Horas de ejercicio")
plt.legend()
plt.show()

# %% [markdown]
# # TRABAJO PRACTICO N 4

# %% [markdown]
# **Trabajo Practico Nº 4**
# Analisis sobre data set
#
# 1= Buscar los siguiente data set en la web
# * Titanic
# * Iris
# * Wine
# * Indian Diabetes
#
# 2- Explicar un data set , sus diferente Variables\
# 3- Deside justificando tu respuesta que tipo de categoria de variable son\
# 4- Detectar y arreglar los siguientes coceptos
# * Valores Ausente
# * Valores Atipicos
#
# 5- Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?\
#
# 6- Realizar analisis univariados
# * Grafico de frecuencia
# * Grafico de torta
# * Histograma
# * etc
#
# 7- En base a los graficos del punto 6 realizar distintas concluciones\
#
# 8- Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\
#
# PD Pueden Buscar data set de kaggle

# %% [markdown]
# ▶ EJERCICIO 1:
# DATA SET SELECCIONADO TITANIC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/mrBronnWow/Curso_Beginners/main/1_Dataset_titanic/train.csv')

# %% [markdown]
# EJERCICIO 2: Explicar un data set, sus diferentes variables

# %%
print(titanic.head())

print("\ntamaño de este dataset es: ", titanic.shape)

print('''\nLos datos que contiene, de los que viajaban en el Titanic: Número de pasajero, Si sobrevivió, Nombre, Sexo, Edad, Valor SibSp(familia), valor Parch(cantidad de padres y/o hijos), Número de Ticket,
Tarifa, Cabina,  Embarque ''')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# tamaño de este dataset es:  (891, 12)
#
# Los datos que contiene, de los que viajaban en el Titanic: Número de pasajero, Si sobrevivió, Nombre, Sexo, Edad, Valor SibSp(familia), valor Parch(cantidad de padres y/o hijos), Número de Ticket,
# Tarifa, Cabina,  Embarque

# %% [markdown]
# EJERCICIO 3: Decide justificando tu respuesta que tipo de categoria de variable son

# %%
"""
Esta base de datos posee datos numéricos discretos,
También tiene datos binarios, numéricos, de carácter discreto,
referidos a si la persona falleció o no en el hecho.
También posee datos de texto tipo string relacionados con el nombre
 de la persona y el lugar de embarque; datos categóricos nominales,
en el género; datos numéricos continuos, en la edad y la tarifa
"""
# Out:
# '\nEsta base de datos posee datos numéricos discretos, \nTambién tiene datos binarios, numéricos, de carácter discreto,\nreferidos a si la persona falleció o no en el hecho. \nTambién posee datos de texto tipo string relacionados con el nombre\n de la persona y el lugar de embarque; datos categóricos nominales,\nen el género; datos numéricos continuos, en la edad y la tarifa\n'

# %% [markdown]
# EJERCICIO 4: DETECTAR Y ARREGLAR LOS SIGUIENTES CONCEPTOS
#  VALORES AUSENTES Y VALORES ATIPICOS

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# EJERCICIO 5:

# %% [markdown]
# Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?

# %%
#Relleno valores faltantes en columna Age
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)

titanic_cleaned=titanic.drop('Cabin',axis='columns') #borra la columna "numero de cabina"

titanic_cleaned
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['PassengerId'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['Survived'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['Pclass'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['Age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['PassengerId'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['Survived'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['Pclass'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['Age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(titanic_cleaned, *['Sex'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(titanic_cleaned, *['Embarked'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(titanic_cleaned, *[[['PassengerId', 'Survived'], ['Survived', 'Pclass'], ['Pclass', 'Age'], ['Age', 'SibSp']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(titanic_cleaned, *['Sex', 'Embarked'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['PassengerId', 'Sex'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['PassengerId', 'Embarked'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['Survived', 'Sex'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['Survived', 'Embarked'], **{'inner': 'box'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Survived', 'Sex'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Survived', 'Embarked'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Pclass', 'Sex'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Pclass', 'Embarked'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['PassengerId'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['Survived'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['Pclass'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(titanic_cleaned, *['Age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['PassengerId'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['Survived'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['Pclass'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(titanic_cleaned, *['Age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(titanic_cleaned, *['Sex'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(titanic_cleaned, *['Embarked'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(titanic_cleaned, *[[['PassengerId', 'Survived'], ['Survived', 'Pclass'], ['Pclass', 'Age'], ['Age', 'SibSp']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(titanic_cleaned, *['Sex', 'Embarked'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['PassengerId', 'Sex'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['PassengerId', 'Embarked'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['Survived', 'Sex'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(titanic_cleaned, *['Survived', 'Embarked'], **{'inner': 'box'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Survived', 'Sex'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Survived', 'Embarked'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Pclass', 'Sex'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(titanic_cleaned, *['PassengerId', 'Pclass', 'Embarked'], **{})
# chart

# %% [markdown]
# EJERCICIO 6- Realizar analisis univariados
# * Grafico de frecuencia
# * Grafico de torta
# * Histograma
# * etc

# %%
sns.countplot(x='Sex', data=titanic_cleaned)
plt.title("Por género")
plt.show()

# %%
sns.countplot(x='Survived', data=titanic_cleaned)
plt.title('''Pasajeros que sobrevivieron o no''')
plt.show()

# %%
sns.countplot(x='Pclass', data=titanic_cleaned)
plt.title("Pasajeros por Clase")
plt.show()

# %% [markdown]
# 7- En base a los graficos del punto 6 realizar distintas concluciones\

# %%
#estuve con mucho trabajo, no llegué a completar este punto

# %% [markdown]
# EJERCICIO 8:
# Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\

# %%
#Eliminar outliers
def detect_outliers_iqr(data, column):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = data[(titanic_cleaned[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

# Llamamos a la función para cada columna numérica donde desees detectar outliers
columns_to_check = ["Age"]
outliers_list = []
for col in columns_to_check:
    outliers = detect_outliers_iqr(titanic_cleaned, col)
    outliers_list.append(outliers)

# Concatenamos todos los outliers encontrados en un solo DataFrame
outliers_df = pd.concat(outliers_list)

# Eliminamos los outliers
df_cleaned = titanic_cleaned.drop(outliers_df.index)

# Imprimimos la cantidad de outliers
print("Número de outliers detectados:", len(outliers_df))
#print(outliers)
# Out:
# Número de outliers detectados: 66

# %%
df_cleaned.boxplot('Age')
print("\n grafico sin tantos outliers")
# Out:
#  grafico sin tantos outliers

# %%
correlation_matrix = df_cleaned[['Survived', 'Age', 'Pclass', 'Fare', 'SibSp']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
"""
No existe relacion entre la edad y si sobrevivio o no,
ni con la edad o la Clase de pasajero, pero si se ve
una pequeña correlacion entre la Tarifa que pagaron y la supervivencia.
"""
# Out:
# '\nNo existe relacion entre la edad y si sobrevivio o no,\nni con la edad o la Clase de pasajero, pero si se ve \nuna pequeña correlacion entre la Tarifa que pagaron y la supervivencia.\n'
